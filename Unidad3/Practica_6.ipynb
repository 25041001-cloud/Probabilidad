# %% [markdown]
# <a href="https://colab.research.google.com/github/25041001-cloud/Probabilidad/blob/main/Unidad3/Practica_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 3
#
# ###Facilitador: José Gabriel Rodriguez Rivas
#
# ###Alumno: Luis Ángel Álvarez García
#
# ###**Programa 6:** **Ejercicio de variable aleatoria discreta no 1**

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
#Verificar que las probabilidades sumen 1
x=[0,1,2,3,4,5]
p=[0.10,0.25,0.30,0.20,0.10,0.05]

sumaProbabilidades=sum(p)
print("La suma de probabilidades:",sumaProbabilidades)
# Out:
# La suma de probabilidades: 1.0

# %%
#Graficar la distribución de probabilidad

plt.stem(x,p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Celulas por muestra")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()

# %%
#Calcular valor esperado E(X)
#Inicializar una variable para acumular la suma
esperanza=0

#Recorrer los valores y sus probabilidades
for i in range(len(x)):
  xi = x[i]   #Valor de la variable aleatoria
  pi = p[i]   #Probabilidad de ese valor
  producto=xi*pi    #Multiplicar valor por su probabilidad
  esperanza += producto    #sumar al acumulador

  #Mostrar cada paso
  print(f"x={xi}, p={pi}, x*p={producto:.2f}")

#Mostrar resultado final
print(f"\nEsperanza: {esperanza:.2f}")
# Out:
# x=0, p=0.1, x*p=0.00
# x=1, p=0.25, x*p=0.25
# x=2, p=0.3, x*p=0.60
# x=3, p=0.2, x*p=0.60
# x=4, p=0.1, x*p=0.40
# x=5, p=0.05, x*p=0.25
#
# Esperanza: 2.10

# %%
#Calcular varianza y desviación estandar

#Calcular E(x^2)
esperanza_cuadrado=0
for i in range(len(x)):
  esperanza_cuadrado += (x[i]**2)*p[i]

#Calcular varianza y desviación estandar
varianza=esperanza_cuadrado-esperanza**2
desviación=math.sqrt(varianza)

#Mostrar resultados
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza: {varianza:.2f}")
print(f"Desviación estandar={desviación:.2f}")
# Out:
# E(X)=2.10
# E(X^2)=6.10
# Varianza: 1.69
# Desviación estandar=1.30

# %%
#Calcular la función de distribución acumulada
F=np.cumsum(p)

#Mostrar resultados
for xi,fi in zip(x,F):
  print(f"F({xi}) = {fi:.2f}")

#Graficar
plt.step(x,F,where="post")
plt.title("Funcion de distribución acumulada (FDA)")
plt.xlabel("Número de células anormales")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0,1.05)
plt.show()
# Out:
# F(0) = 0.10
# F(1) = 0.35
# F(2) = 0.65
# F(3) = 0.85
# F(4) = 0.95
# F(5) = 1.00

# %% [markdown]
# ##Interpretaciones
#
# El promedio esperado de celulas anormales por muestra es de 2 por muestra
#
# No hay tanta variabilidad, pues la desviación estandar está cerca de 1 y 3
#
# La función acumulada indica que es mucho más probable encontrar un número bajo de células anormales que un numero alto
