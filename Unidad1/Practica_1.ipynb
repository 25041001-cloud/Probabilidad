# %% [markdown]
# <a href="https://colab.research.google.com/github/25041001-cloud/Probabilidad/blob/main/Unidad1/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 1
#
# ###Facilitador: José Gabriel Rodriguez Rivas
#
# ###Alumno: Luis Ángel Álvarez García
#
# ###**Programa 1:** **Estadística básica e histograma**

# %% [markdown]
# ###**Importar librería statistics**

# %%
from statistics import *

# %% [markdown]
# ##Ejemplo 1

# %%
# Lista de calificaciones del grupo a de probabilidad y estadística
grupos=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupos)
type(grupos)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %% [markdown]
# ##Determinar Media

# %%
#sacar la media de las calificaciones con una formula
promedio=sum(grupos)/len(grupos)
print(promedio)
# Out:
# 75.33333333333333

# %%
#Utilizar la función mean que esta en la librería statistics para sacar
#el promedio

promedio2=mean(grupos)
print(promedio2)
# Out:
# 75.33333333333333

# %% [markdown]
# ##Determinar mediana

# %%
#sacar la mediana de las calificaciones con función median
mediana=median(grupos)
print(mediana)
# Out:
# 76.5

# %% [markdown]
# ##Determinar moda

# %%
#sacar la moda de las calificaciones con la funcion mode
moda=mode(grupos)
print(moda)
# Out:
# 70

# %%
#sacar más de una moda con la función multimode
moda2=multimode(grupos)
print(moda2)
# Out:
# [70, 100]

# %% [markdown]
# #Ejemplo 2: Tiempos de 100 metros de un grupo de 10 alumnos

# %%
#definimos una variable llamada tiempos100mts de tipo lista que contiene los tiempos que tardaron los 10 alumnos para correr los 100 metros
tiempos100mts=[15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

#Desplegamos los valores de la lista
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %% [markdown]
# ##Funcion mean para calcular el promedio, mediana y moda

# %%
promedio=mean(tiempos100mts)
#imprimir el promedio
print("El promedio de los tiempos de los alumnos es:", promedio)

mediana=median(tiempos100mts)
#imprimir la mediana
print("La mediana de los tiempos de los alumnos es:", mediana)

moda=mode(tiempos100mts)
#imprimir la moda
print("La moda de los tiempos de los alumnos es:", moda)
# Out:
# El promedio de los tiempos de los alumnos es: 17.322
# La mediana de los tiempos de los alumnos es: 17.2
# La moda de los tiempos de los alumnos es: 15.1

# %% [markdown]
# #Ejemplo 3: Histogramas de 2 grupos

# %%
#librería para generar números aleatorios
import random

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [53.56, 97.63, 86.96, 94.22, 71.71, 81.61, 56.8, 76.22, 55.95, 53.78, 88.81, 79.76, 62.44, 98.81, 62.83, 66.92, 61.48, 99.36, 80.0, 91.89, 57.9, 86.99, 87.45, 75.38, 62.69, 54.21, 93.83, 65.74, 98.42, 53.34, 73.74, 52.81, 69.73, 93.08, 62.82, 50.17, 51.94, 92.89, 76.59, 56.3, 57.61, 62.14, 79.06, 92.46, 73.17, 80.13, 63.77, 69.33, 76.36, 96.7, 51.29, 57.61, 66.73, 82.71, 86.67, 72.02, 84.16, 70.13, 83.77, 99.68, 68.83, 65.26, 80.8, 56.8, 86.71, 69.34, 72.61, 85.56, 64.26, 98.58, 65.11, 62.68, 85.28, 81.12, 82.3, 68.29, 86.06, 91.53, 78.42, 76.05, 54.19, 84.09, 83.6, 82.54, 58.87, 93.3, 81.84, 91.41, 81.34, 58.44, 66.68, 89.79, 85.84, 98.99, 92.91, 93.85, 95.63, 62.11, 65.76, 67.83]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(70,100),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [86.15, 82.48, 91.51, 98.21, 75.92, 98.53, 70.01, 76.42, 81.19, 99.0, 78.73, 88.92, 86.6, 82.6, 71.53, 76.54, 94.69, 71.28, 75.06, 74.67, 96.86, 95.48, 90.08, 96.42, 83.08, 76.34, 87.07, 71.05, 84.21, 89.29, 73.44, 77.37, 85.33, 72.27, 85.92, 75.83, 75.69, 81.02, 76.78, 77.57, 96.67, 93.17, 70.21, 85.03, 89.69, 94.4, 76.78, 70.54, 73.26, 93.8, 83.1, 96.8, 77.38, 73.73, 75.62, 89.49, 90.9, 97.24, 83.71, 87.33, 98.26, 78.88, 90.37, 70.42, 81.7, 72.49, 78.09, 76.69, 73.43, 85.61, 84.76, 75.8, 90.07, 98.86, 87.88, 83.16, 99.66, 77.17, 90.86, 98.08, 82.86, 87.23, 93.2, 90.33, 86.31, 98.29, 72.51, 92.94, 96.34, 97.06, 98.5, 99.9, 83.13, 98.21, 76.15, 84.16, 87.35, 92.84, 96.91, 84.12]

# %% [markdown]
# ###Importar librería matplot para graficar valores

# %%
#libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title('Producción diaria de la fabrica 1')

(0.5, 1.0, 'Producción diaria de la fabrica 1')
# Out:
# (0.5, 1.0, 'Producción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title('Producción diaria de la fabrica 2')

(0.5, 1.0, 'Producción diaria de la fabrica 2')
# Out:
# (0.5, 1.0, 'Producción diaria de la fabrica 2')

# %%
#calcular media mediana y moda de la fabrica 1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)

print("Valores de la fabrica 1")
print('La media es:',media1)
print('La mediana es:',mediana1)
print('La moda es:',moda1)
# Out:
# Valores de la fabrica 1
# La media es: 75.5686
# La mediana es: 76.28999999999999
# La moda es: 56.8

# %%
#calcular media mediana y moda de la fabrica 2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)

print("Valores de la fabrica 2")
print('La media es:',media2)
print('La mediana es:',mediana2)
print('La moda es:',moda2)
# Out:
# Valores de la fabrica 2
# La media es: 85.0057
# La mediana es: 84.89500000000001
# La moda es: 98.21

# %%
#generar 2 sobplot de 1 renglon por 2 columnas para desplegar los 2 histogramas
#una al lado de la otra
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
