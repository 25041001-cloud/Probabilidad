# %% [markdown]
# <a href="https://colab.research.google.com/github/25041001-cloud/Probabilidad/blob/main/Unidad1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 1
#
# ###Facilitador: José Gabriel Rodriguez Rivas
#
# ###Alumno: Luis Ángel Álvarez García
#
# ###**Programa 3:** **Tablas de frecuencias**

# %%
#basado en el LIBRO estadística para administración página 12
#creamos una lista vacía que representa la edad de 100 personas
import random
edades=[]
#Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
  #generamos un número aleatorio con la función randit y lo guardamos en la variable
  #numero_aleatorio
  numero_aleatorio=random.randint(18,70)
  #Agregamos el número aleatorio a la lista de valores
  edades.append(numero_aleatorio)
#imprimimos la lista de edades
print(edades)
# Out:
# [27, 46, 21, 54, 33, 23, 51, 21, 43, 53, 66, 20, 49, 53, 65, 28, 59, 39, 30, 52, 44, 37, 45, 28, 26, 32, 61, 65, 37, 60, 26, 49, 45, 49, 24, 63, 32, 70, 41, 53, 40, 23, 32, 60, 48, 36, 24, 69, 61, 59, 36, 61, 61, 65, 67, 60, 24, 45, 63, 42, 58, 63, 43, 19, 28, 48, 57, 43, 41, 24, 27, 66, 33, 51, 46, 39, 37, 60, 39, 31, 55, 46, 44, 49, 54, 25, 66, 53, 38, 27, 24, 45, 46, 39, 42, 41, 19, 25, 27, 53]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los números aleatorios
df=pd.DataFrame(edades,columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    27
# 1    46
# 2    21
# 3    54
# 4    33

# %%
#Calcular la tabla de distribución de frecuencias
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')

#imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 26    19           2
# 31    20           1
# 17    21           2
# 21    23           2
# 1     24           5
# 27    25           2
# 24    26           2
# 7     27           4
# 14    28           3
# 30    30           1
# 39    31           1
# 11    32           3
# 20    33           2
# 23    36           2
# 10    37           3
# 41    38           1
# 6     39           4
# 33    40           1
# 12    41           3
# 28    42           2
# 9     43           3
# 22    44           2
# 3     45           4
# 2     46           4
# 29    48           2
# 8     49           4
# 18    51           2
# 32    52           1
# 0     53           5
# 19    54           2
# 40    55           1
# 38    57           1
# 37    58           1
# 25    59           2
# 5     60           4
# 4     61           4
# 13    63           3
# 16    65           3
# 15    66           3
# 34    67           1
# 35    69           1
# 36    70           1

# %% [markdown]
# ##Calcular la frecuencia relativa

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 26    19           2           0.02
# 31    20           1           0.01
# 17    21           2           0.02
# 21    23           2           0.02
# 1     24           5           0.05
# 27    25           2           0.02
# 24    26           2           0.02
# 7     27           4           0.04
# 14    28           3           0.03
# 30    30           1           0.01
# 39    31           1           0.01
# 11    32           3           0.03
# 20    33           2           0.02
# 23    36           2           0.02
# 10    37           3           0.03
# 41    38           1           0.01
# 6     39           4           0.04
# 33    40           1           0.01
# 12    41           3           0.03
# 28    42           2           0.02
# 9     43           3           0.03
# 22    44           2           0.02
# 3     45           4           0.04
# 2     46           4           0.04
# 29    48           2           0.02
# 8     49           4           0.04
# 18    51           2           0.02
# 32    52           1           0.01
# 0     53           5           0.05
# 19    54           2           0.02
# 40    55           1           0.01
# 38    57           1           0.01
# 37    58           1           0.01
# 25    59           2           0.02
# 5     60           4           0.04
# 4     61           4           0.04
# 13    63           3           0.03
# 16    65           3           0.03
# 15    66           3           0.03
# 34    67           1           0.01
# 35    69           1           0.01
# 36    70           1           0.01

# %% [markdown]
# ##Calcular la frecuencia Porcentual

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 26    19           2           0.02              2.0
# 31    20           1           0.01              1.0
# 17    21           2           0.02              2.0
# 21    23           2           0.02              2.0
# 1     24           5           0.05              5.0
# 27    25           2           0.02              2.0
# 24    26           2           0.02              2.0
# 7     27           4           0.04              4.0
# 14    28           3           0.03              3.0
# 30    30           1           0.01              1.0
# 39    31           1           0.01              1.0
# 11    32           3           0.03              3.0
# 20    33           2           0.02              2.0
# 23    36           2           0.02              2.0
# 10    37           3           0.03              3.0
# 41    38           1           0.01              1.0
# 6     39           4           0.04              4.0
# 33    40           1           0.01              1.0
# 12    41           3           0.03              3.0
# 28    42           2           0.02              2.0
# 9     43           3           0.03              3.0
# 22    44           2           0.02              2.0
# 3     45           4           0.04              4.0
# 2     46           4           0.04              4.0
# 29    48           2           0.02              2.0
# 8     49           4           0.04              4.0
# 18    51           2           0.02              2.0
# 32    52           1           0.01              1.0
# 0     53           5           0.05              5.0
# 19    54           2           0.02              2.0
# 40    55           1           0.01              1.0
# 38    57           1           0.01              1.0
# 37    58           1           0.01              1.0
# 25    59           2           0.02              2.0
# 5     60           4           0.04              4.0
# 4     61           4           0.04              4.0
# 13    63           3           0.03              3.0
# 16    65           3           0.03              3.0
# 15    66           3           0.03              3.0
# 34    67           1           0.01              1.0
# 35    69           1           0.01              1.0
# 36    70           1           0.01              1.0

# %% [markdown]
# ##Calcular la Frecuencia Acumulada

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 26    19           2           0.02              2.0               2
# 31    20           1           0.01              1.0               3
# 17    21           2           0.02              2.0               5
# 21    23           2           0.02              2.0               7
# 1     24           5           0.05              5.0              12
# 27    25           2           0.02              2.0              14
# 24    26           2           0.02              2.0              16
# 7     27           4           0.04              4.0              20
# 14    28           3           0.03              3.0              23
# 30    30           1           0.01              1.0              24
# 39    31           1           0.01              1.0              25
# 11    32           3           0.03              3.0              28
# 20    33           2           0.02              2.0              30
# 23    36           2           0.02              2.0              32
# 10    37           3           0.03              3.0              35
# 41    38           1           0.01              1.0              36
# 6     39           4           0.04              4.0              40
# 33    40           1           0.01              1.0              41
# 12    41           3           0.03              3.0              44
# 28    42           2           0.02              2.0              46
# 9     43           3           0.03              3.0              49
# 22    44           2           0.02              2.0              51
# 3     45           4           0.04              4.0              55
# 2     46           4           0.04              4.0              59
# 29    48           2           0.02              2.0              61
# 8     49           4           0.04              4.0              65
# 18    51           2           0.02              2.0              67
# 32    52           1           0.01              1.0              68
# 0     53           5           0.05              5.0              73
# 19    54           2           0.02              2.0              75
# 40    55           1           0.01              1.0              76
# 38    57           1           0.01              1.0              77
# 37    58           1           0.01              1.0              78
# 25    59           2           0.02              2.0              80
# 5     60           4           0.04              4.0              84
# 4     61           4           0.04              4.0              88
# 13    63           3           0.03              3.0              91
# 16    65           3           0.03              3.0              94
# 15    66           3           0.03              3.0              97
# 34    67           1           0.01              1.0              98
# 35    69           1           0.01              1.0              99
# 36    70           1           0.01              1.0             100

# %% [markdown]
# #Regla de Sturges
#
# ###Es una regla que sirve para calcular el número de clases o intervalos idóneo en los que se debe dividir un conjunto de datos
# ###Establece que el número de clases es igual a uno o más el logaritmo en base dos del número total de datos
#
# ###1+log (base 2) * N
#
# ###Donde N es el tamaño de la muestra

# %%
#Importamos la librería math de funciones matemáticas
import math

# %%
#Volvemos a usar la lista edades
print(edades)
# Out:
# [27, 46, 21, 54, 33, 23, 51, 21, 43, 53, 66, 20, 49, 53, 65, 28, 59, 39, 30, 52, 44, 37, 45, 28, 26, 32, 61, 65, 37, 60, 26, 49, 45, 49, 24, 63, 32, 70, 41, 53, 40, 23, 32, 60, 48, 36, 24, 69, 61, 59, 36, 61, 61, 65, 67, 60, 24, 45, 63, 42, 58, 63, 43, 19, 28, 48, 57, 43, 41, 24, 27, 66, 33, 51, 46, 39, 37, 60, 39, 31, 55, 46, 44, 49, 54, 25, 66, 53, 38, 27, 24, 45, 46, 39, 42, 41, 19, 25, 27, 53]

# %%
#Crear un DataFrame con las edades
df=pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     27
# 1     46
# 2     21
# 3     54
# 4     33
# ..   ...
# 95    41
# 96    19
# 97    25
# 98    27
# 99    53
#
# [100 rows x 1 columns]

# %%
#Calcular el número de intervalos utilizando la regla de Sturges
n=len(edades)
k=int(1+math.log2(n))
print("Valor de n=",n,"\nNúmero de intervalos=",k)
# Out:
# Valor de n= 100
# Número de intervalos= 7

# %%
#crear la tabla de frecuencia
tabla_frecuencia=pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns=['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.857, 48.143]    20
# 1  (18.948, 26.286]    16
# 2  (48.143, 55.429]    15
# 3  (26.286, 33.571]    14
# 4  (55.429, 62.714]    12
# 5    (62.714, 70.0]    12
# 6  (33.571, 40.857]    11

# %%
#Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia=tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (18.948, 26.286]    16
# 3  (26.286, 33.571]    14
# 6  (33.571, 40.857]    11
# 0  (40.857, 48.143]    20
# 2  (48.143, 55.429]    15
# 4  (55.429, 62.714]    12
# 5    (62.714, 70.0]    12

# %%
#Generar columnas siguientes
tabla_frecuencia['Frec Rel']=tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec Porc']=tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec Ac']=tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac']=tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac']=tabla_frecuencia['Frec Porc'].cumsum()

#Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (18.948, 26.286]    16      0.16       16.0       16         0.16
# 3  (26.286, 33.571]    14      0.14       14.0       30         0.30
# 6  (33.571, 40.857]    11      0.11       11.0       41         0.41
# 0  (40.857, 48.143]    20      0.20       20.0       61         0.61
# 2  (48.143, 55.429]    15      0.15       15.0       76         0.76
# 4  (55.429, 62.714]    12      0.12       12.0       88         0.88
# 5    (62.714, 70.0]    12      0.12       12.0      100         1.00
#
#    Frec Porc Ac
# 1          16.0
# 3          30.0
# 6          41.0
# 0          61.0
# 2          76.0
# 4          88.0
# 5         100.0

# %%
#Importamos la librería matplotlib para generar un histograma
import matplotlib.pyplot as plt

# %%
plt.hist(edades, alpha=0.5)
plt.title('Histograma de edades basado en la función de matplotlib con valores estandar')
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estandar')

# %%
#Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=k, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
