# %% [markdown]
# <a href="https://colab.research.google.com/github/25041001-cloud/Probabilidad/blob/main/Unidad1/Pr%C3%A1ctica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 1
#
# ###Facilitador: José Gabriel Rodriguez Rivas
#
# ###Alumno: Luis Ángel Álvarez García
#
# ###**Programa 5:** **Estadística descriptiva**

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot

# %%
#Cargar el archivo CDV en una variable llamada covid
covid=pd.read_csv("20-06-30-COVID19MEXICO - codificado.csv",encoding="ISO-8859-1")

# %%
#Mostrar la información del archivo.
#Muestra el numero de registros, tipo de datos de la columna, valores nulos, memoria

covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297754 entries, 0 to 297753
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ï»¿ORIGEN       297754 non-null  int64
#  1   SECTOR          297754 non-null  int64
#  2   SEXO            297754 non-null  object
#  3   ENTIDAD_NAC     297754 non-null  object
#  4   TIPO_PACIENTE   297754 non-null  object
#  5   FECHA_INGRESO   297754 non-null  object
#  6   FECHA_SINTOMAS  297754 non-null  object
#  7   FECHA_DEF       297754 non-null  object
#  8   INTUBADO        297754 non-null  object
#  9   NEUMONIA        297754 non-null  object
#  10  EDAD            297754 non-null  int64
#  11  EMBARAZO        297754 non-null  object
#  12  DIABETES        297754 non-null  object
#  13  EPOC            297754 non-null  object
#  14  ASMA            297754 non-null  object
#  15  INMUSUPR        297754 non-null  object
#  16  HIPERTENSION    297754 non-null  object
#  17  CARDIOVASCULAR  297754 non-null  object
#  18  OBESIDAD        297754 non-null  object
#  19  RENAL_CRONICA   297754 non-null  object
#  20  TABAQUISMO      297754 non-null  object
#  21  RESULTADO       297754 non-null  object
#  22  UCI             297754 non-null  object
# dtypes: int64(3), object(20)
# memory usage: 52.2+ MB
