# %% [markdown]
# <a href="https://colab.research.google.com/github/25041001-cloud/Probabilidad/blob/main/Unidad5/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 5
#
# ###Facilitador: José Gabriel Rodriguez Rivas
#
# ###Alumno: Luis Ángel Álvarez García
#
# ###**Programa 1**: **Regresión Lineal y Correlación**

# %%
from sklearn.linear_model import LinearRegression #Modelo de regresión lineal
import numpy as np

#Datos de entrada
periodos=[2018,2019,2020,2021,2022,2023]
inversion=np.array([2,3,5,4,11,5]).reshape(-1,1)
ganancias=[20,25,34,30,40,31]

#Crear y entrenar el modelo de regresión lineal
modelo=LinearRegression()
modelo.fit(inversion,ganancias)

#Predecir la ganancia para el año 2024
ganancia_2024=modelo.predict([[8]])

print("La ganancia esperada para el año 2024 es de: ",ganancia_2024[0])

#Coeficientes de la regresión
print("coeficiente de la pendiente (m): ",modelo.coef_[0])
print("Interpretación de la recta (b): ",modelo.intercept_)
# Out:
# La ganancia esperada para el año 2024 es de:  36.0
# coeficiente de la pendiente (m):  2.0000000000000004
# Interpretación de la recta (b):  20.0
